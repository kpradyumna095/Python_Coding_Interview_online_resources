# %%
import pandas as pd
import numpy as np
import nltk
import re

# %%
df = pd.DataFrame({"short_description":["unable to login to microsoft teams",
                                         "global protect login issue",
                                         "not able to connect vpn",
                                         "adobe2 installation issue",
                                         "windows10 system reset issue",
                                         "webex password reset issue",
                                         "sever1235 loading problem",
                                         "not able to configure webex meeting on mobile, windows8.0 pc"],
                   })
df
# Out:
#                                    short_description
# 0                 unable to login to microsoft teams
# 1                         global protect login issue
# 2                            not able to connect vpn
# 3                          adobe2 installation issue
# 4                       windows10 system reset issue
# 5                         webex password reset issue
# 6                          sever1235 loading problem
# 7  not able to configure webex meeting on mobile,...

# %%
df.shape
# Out:
# (8, 1)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                    short_description
# 0                 unable to login to microsoft teams
# 1                         global protect login issue
# 2                            not able to connect vpn
# 3                          adobe2 installation issue
# 4                       windows10 system reset issue
# 5                         webex password reset issue
# 6                          sever1235 loading problem
# 7  not able to configure webex meeting on mobile,...>

# %% [markdown]
#     Make the text lowercase
#     Remove text in square brackets
#     Remove punctuation
#     Remove words containing numbers

# %%
def clean_data(text):
    text = text.lower() # text to lowercase
    text = re.sub(r'\s\{\$\S*', '',text) # Remove text within curly braces
    text = re.sub(r'\n', '', text) # Remove line breaks
    text = re.sub(r'\(\w*\)', '', text) #remove text within braces
    text = re.sub(r'(\W\s)|(\W$)|(\W\d*)', ' ',text) # Remove punctuation
    text = re.sub(r'x+((/xx)*/\d*\s*)|x*', '',text) #Remove date
    text = re.sub(r'\d+\s', '', text) #Remove other numerical values
    text = re.sub(r' +', ' ',text) #Remove unnecessary white spaces
    return text

# %%
# Apply data cleaning to the complaints_what_happened column

df['complaints'] = df['short_description'].apply(clean_data)
df.head()
# Out:
#                     short_description                          complaints
# 0  unable to login to microsoft teams  unable to login to microsoft teams
# 1          global protect login issue          global protect login issue
# 2             not able to connect vpn             not able to connect vpn
# 3           adobe2 installation issue             adobeinstallation issue
# 4        windows10 system reset issue           windowssystem reset issue

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from pprint import pprint

from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
import json 
import numpy as np
import pandas as pd
import re, nltk, spacy, string
import en_core_web_sm
nlp = en_core_web_sm.load()
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from plotly.offline import plot
import plotly.graph_objects as go
import plotly.express as px

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from pprint import pprint

# %%
#Write your function to Lemmatize the texts
from nltk.tokenize import word_tokenize
nltk.download('punkt')
from nltk.corpus import stopwords
nltk.download('stopwords')
import nltk
from nltk.corpus import wordnet as wn
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem.wordnet import WordNetLemmatizer
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
wordnet_lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
# Function to Lemmatize the texts
def lemmatization(text):
    tokens = word_tokenize(text)
    wordnet_lemmetizer = WordNetLemmatizer()
    lemmatized = [wordnet_lemmetizer.lemmatize(token) for token in tokens]
    lemmatized_str = " ".join(lemmatized)
    return lemmatized_str

# %%
#Create a dataframe('df_clean') that will have only the complaints and the lemmatized complaints 
df_clean = pd.DataFrame({'complaints':df['complaints'], 'lemmatized':df['complaints'].apply(lemmatization)})

# %%
df_clean.head()
# Out:
#                            complaints                         lemmatized
# 0  unable to login to microsoft teams  unable to login to microsoft team
# 1          global protect login issue         global protect login issue
# 2             not able to connect vpn            not able to connect vpn
# 3             adobeinstallation issue            adobeinstallation issue
# 4           windowssystem reset issue          windowssystem reset issue

# %%
def lemmatize(text):      
    sent = [wordnet_lemmatizer.lemmatize(word) for word in word_tokenize(text) if not word in set(stopwords.words('english'))]
    return " ".join(sent)

# %%
df_clean['lemmatized'] = df_clean['lemmatized'].apply(lambda x : lemmatize(x))

# %%
df_clean.head()
# Out:
#                            complaints                   lemmatized
# 0  unable to login to microsoft teams  unable login microsoft team
# 1          global protect login issue   global protect login issue
# 2             not able to connect vpn             able connect vpn
# 3             adobeinstallation issue      adobeinstallation issue
# 4           windowssystem reset issue    windowssystem reset issue
